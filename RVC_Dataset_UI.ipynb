# %%
#@title Clone & Run
# !git clone https://github.com/yaranbarzi/RVC-Dataset.git

# !apt install aria2

# !pip install audio-separator[gpu]==0.17.5 demucs aria2p yt-dlp ort-nightly-gpu noisereduce librosa soundfile gradio numpy scipy pydub
# !cd /content/RVC-Dataset && python app.py

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# #### در صورتی که در محیط گریدیو موفق به دانلود نشدید از سلولهای زیر برای دانلود استفاده کنید

# %%
#@title دانلود فایل ترکیب شده صداها
from google.colab import files
files.download('/content/RVC-Dataset/output/combined_vocals.wav')

# %%
#@title دانلود فایل نهایی
from google.colab import files
files.download('/content/RVC-Dataset/output/final_processed.wav')
